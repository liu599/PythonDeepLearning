# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    x = x - learning_rate * gradx
    # Return the new value for x
    return x


def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x

import random
# Random number between 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# TODO: Set the learning rate
learning_rate = 0.1
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 1142766.000, x = 2138.000
# EPOCH 1: Cost = 731372.040, x = 1710.400
# EPOCH 2: Cost = 468079.906, x = 1368.320
# EPOCH 3: Cost = 299572.940, x = 1094.656
# EPOCH 4: Cost = 191728.481, x = 875.725
# EPOCH 5: Cost = 122708.028, x = 700.580
# EPOCH 6: Cost = 78534.938, x = 560.464
# EPOCH 7: Cost = 50264.160, x = 448.371
# EPOCH 8: Cost = 32170.863, x = 358.697
# EPOCH 9: Cost = 20591.152, x = 286.958
# EPOCH 10: Cost = 13180.137, x = 229.566
# EPOCH 11: Cost = 8437.088, x = 183.653
# EPOCH 12: Cost = 5401.536, x = 146.922
# EPOCH 13: Cost = 3458.783, x = 117.538
# EPOCH 14: Cost = 2215.421, x = 94.030
# EPOCH 15: Cost = 1419.670, x = 75.224
# EPOCH 16: Cost = 910.389, x = 60.179
# EPOCH 17: Cost = 584.449, x = 48.143
# EPOCH 18: Cost = 375.847, x = 38.515
# EPOCH 19: Cost = 242.342, x = 30.812
# EPOCH 20: Cost = 156.899, x = 24.649
# EPOCH 21: Cost = 102.215, x = 19.720
# EPOCH 22: Cost = 67.218, x = 15.776
# EPOCH 23: Cost = 44.819, x = 12.621
# EPOCH 24: Cost = 30.484, x = 10.096
# EPOCH 25: Cost = 21.310, x = 8.077
# EPOCH 26: Cost = 15.438, x = 6.462
# EPOCH 27: Cost = 11.681, x = 5.169
# EPOCH 28: Cost = 9.276, x = 4.135
# EPOCH 29: Cost = 7.736, x = 3.308
# EPOCH 30: Cost = 6.751, x = 2.647
# EPOCH 31: Cost = 6.121, x = 2.117
# EPOCH 32: Cost = 5.717, x = 1.694
# EPOCH 33: Cost = 5.459, x = 1.355
# EPOCH 34: Cost = 5.294, x = 1.084
# EPOCH 35: Cost = 5.188, x = 0.867
# EPOCH 36: Cost = 5.120, x = 0.694
# EPOCH 37: Cost = 5.077, x = 0.555
# EPOCH 38: Cost = 5.049, x = 0.444
# EPOCH 39: Cost = 5.032, x = 0.355
# EPOCH 40: Cost = 5.020, x = 0.284
# EPOCH 41: Cost = 5.013, x = 0.227
# EPOCH 42: Cost = 5.008, x = 0.182
# EPOCH 43: Cost = 5.005, x = 0.146
# EPOCH 44: Cost = 5.003, x = 0.116
# EPOCH 45: Cost = 5.002, x = 0.093
# EPOCH 46: Cost = 5.001, x = 0.074
# EPOCH 47: Cost = 5.001, x = 0.060
# EPOCH 48: Cost = 5.001, x = 0.048
# EPOCH 49: Cost = 5.000, x = 0.038
# EPOCH 50: Cost = 5.000, x = 0.031
# EPOCH 51: Cost = 5.000, x = 0.024
# EPOCH 52: Cost = 5.000, x = 0.020
# EPOCH 53: Cost = 5.000, x = 0.016
# EPOCH 54: Cost = 5.000, x = 0.012
# EPOCH 55: Cost = 5.000, x = 0.010
# EPOCH 56: Cost = 5.000, x = 0.008
# EPOCH 57: Cost = 5.000, x = 0.006
# EPOCH 58: Cost = 5.000, x = 0.005
# EPOCH 59: Cost = 5.000, x = 0.004
# EPOCH 60: Cost = 5.000, x = 0.003
# EPOCH 61: Cost = 5.000, x = 0.003
# EPOCH 62: Cost = 5.000, x = 0.002
# EPOCH 63: Cost = 5.000, x = 0.002
# EPOCH 64: Cost = 5.000, x = 0.001
# EPOCH 65: Cost = 5.000, x = 0.001
# EPOCH 66: Cost = 5.000, x = 0.001
# EPOCH 67: Cost = 5.000, x = 0.001
# EPOCH 68: Cost = 5.000, x = 0.001
# EPOCH 69: Cost = 5.000, x = 0.000
# EPOCH 70: Cost = 5.000, x = 0.000
# EPOCH 71: Cost = 5.000, x = 0.000
# EPOCH 72: Cost = 5.000, x = 0.000
# EPOCH 73: Cost = 5.000, x = 0.000
# EPOCH 74: Cost = 5.000, x = 0.000
# EPOCH 75: Cost = 5.000, x = 0.000
# EPOCH 76: Cost = 5.000, x = 0.000
# EPOCH 77: Cost = 5.000, x = 0.000
# EPOCH 78: Cost = 5.000, x = 0.000
# EPOCH 79: Cost = 5.000, x = 0.000
# EPOCH 80: Cost = 5.000, x = 0.000
# EPOCH 81: Cost = 5.000, x = 0.000
# EPOCH 82: Cost = 5.000, x = 0.000
# EPOCH 83: Cost = 5.000, x = 0.000
# EPOCH 84: Cost = 5.000, x = 0.000
# EPOCH 85: Cost = 5.000, x = 0.000
# EPOCH 86: Cost = 5.000, x = 0.000
# EPOCH 87: Cost = 5.000, x = 0.000
# EPOCH 88: Cost = 5.000, x = 0.000
# EPOCH 89: Cost = 5.000, x = 0.000
# EPOCH 90: Cost = 5.000, x = 0.000
# EPOCH 91: Cost = 5.000, x = 0.000
# EPOCH 92: Cost = 5.000, x = 0.000
# EPOCH 93: Cost = 5.000, x = 0.000
# EPOCH 94: Cost = 5.000, x = 0.000
# EPOCH 95: Cost = 5.000, x = 0.000
# EPOCH 96: Cost = 5.000, x = 0.000
# EPOCH 97: Cost = 5.000, x = 0.000
# EPOCH 98: Cost = 5.000, x = 0.000
# EPOCH 99: Cost = 5.000, x = 0.000
# EPOCH 100: Cost = 5.000, x = 0.000
